# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.stats.multicomp import pairwise_tukeyhsd
pd.set_option('display.max_columns', 20)

# %%
df = pd.read_csv('../datasets/202104-capitalbikeshare-tripdata.csv')
df.head(5)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  F5C4A81C8792FB5D  electric_bike  2021-04-21 10:38:45  2021-04-21 10:46:59
# 1  4A639A0EE09351C7  electric_bike  2021-04-20 20:28:03  2021-04-20 20:28:27
# 2  3405FD412F059E35  electric_bike  2021-04-20 23:22:32  2021-04-20 23:23:51
# 3  E2B1F0E18AF7811E  electric_bike  2021-04-21 13:00:34  2021-04-21 13:02:27
# 4  59FDBFBE03DA25E7  electric_bike  2021-04-20 10:03:55  2021-04-20 10:11:08
#
#   start_station_name  start_station_id end_station_name  end_station_id  \
# 0                NaN               NaN              NaN             NaN
# 1                NaN               NaN              NaN             NaN
# 2                NaN               NaN              NaN             NaN
# 3                NaN               NaN              NaN             NaN
# 4                NaN               NaN              NaN             NaN
#
#    start_lat  start_lng  end_lat  end_lng member_casual
# ...

# %%
df.started_at=df.started_at.apply(lambda x: np.datetime64(x))
df.ended_at=df.ended_at.apply(lambda x: np.datetime64(x))

# %%
sum(df.member_casual=='casual')
# Out:
# 98739

# %%
df_lw = df[df.started_at >=np.datetime64('2021-04-23 23:59:59')]
print(df_lw.shape)
df_lw.head.mem
# Out:
# (49161, 13)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-aa81e568ec84> in <module>
#       1 df_lw = df[df.started_at >=np.datetime64('2021-04-23 23:59:59')]
#       2 print(df_lw.shape)
# ----> 3 df_lw.head.mem
#
# AttributeError: 'function' object has no attribute 'mem'

# %%
from datetime import datetime
def np_to_dt(date):
    list_date = np.datetime64(date).astype('str').split('T')[0].split('-')
    return datetime(int(list_date[0]),int(list_date[1]),int(list_date[2]))
np_to_dt('2021-04-28 20:18:05')
# Out:
# datetime.datetime(2021, 4, 28, 0, 0)

# %%
df[(df.started_at >= np.datetime64('2021-04-14 12:00:00')) & (df.started_at >= np.datetime64('2021-04-14 12:59:59'))]
# Out:
#                  ride_id  rideable_type          started_at  \
# 0       F5C4A81C8792FB5D  electric_bike 2021-04-21 10:38:45
# 1       4A639A0EE09351C7  electric_bike 2021-04-20 20:28:03
# 2       3405FD412F059E35  electric_bike 2021-04-20 23:22:32
# 3       E2B1F0E18AF7811E  electric_bike 2021-04-21 13:00:34
# 4       59FDBFBE03DA25E7  electric_bike 2021-04-20 10:03:55
# ...                  ...            ...                 ...
# 216755  7425A7629E36FBDC    docked_bike 2021-04-19 22:35:02
# 216758  C84D318AFEE77E7C   classic_bike 2021-04-17 13:07:49
# 216760  941642B7BA047303   classic_bike 2021-04-27 17:20:09
# 216761  BF443A5C264FD978   classic_bike 2021-04-30 12:16:48
# 216762  9A64DA954BB2B33B   classic_bike 2021-04-16 16:22:30
#
#                   ended_at              start_station_name  start_station_id  \
# 0      2021-04-21 10:46:59                             NaN               NaN
# 1      2021-04-20 20:28:27                             NaN               NaN
# ...

# %%
###############3
##  NO NEED TO SUM CASUAL AND MEMBER> USE THEIR ENTRIES TO PLOT TOGETHER ON A SINGLE PLOT
#########33
from datetime import datetime
def np_to_dt(date):
    list_date = np.datetime64(date).astype('str').split('T')[0].split('-')
    return datetime(int(list_date[0]),int(list_date[1]),int(list_date[2]))
    
np_to_dt('2021-04-28 20:18:05')
rows = []
days = list([f'0{h}' if h < 10 else str(h) for h in range(24,31,1)])
hours = list([f'0{h}' if h < 10 else str(h) for h in range(0,24,1)])
holiday = np.datetime64('2021-04-16')
columns = ['dteday','season','weekday','hr','holiday','workingday','casual','registered','cnt']
date = '2021-04'
for day in days:
    for hour in hours:
        h_low = f'2021-04-{day} {hour}:00:00'
        h_high = f'2021-04-{day} {hour}:59:59'
        local_df = df[(df.started_at >= np.datetime64(h_low))&(df.started_at <=np.datetime64(h_high))]
        
        casual_count = sum(local_df.member_casual=='casual')
        registered_count=sum(local_df.member_casual=='member')
        total = casual_count+registered_count
        rows.append([np.datetime64(h_low),
        1,
        np_to_dt(f'{date}-{day}').weekday(),
        hour,
        0,
        1,
        casual_count,
        registered_count,
        total])

cnt_df = pd.DataFrame(rows, columns = columns)
cnt_df.workingday = cnt_df.weekday.apply(lambda day : 1 if day < 5  else 0)

# %%
cnt_df
# Out:
#                  dteday  season  weekday  hr  holiday  workingday  casual  \
# 0   2021-04-24 00:00:00       1        5  00        0           0      64
# 1   2021-04-24 01:00:00       1        5  01        0           0      47
# 2   2021-04-24 02:00:00       1        5  02        0           0      19
# 3   2021-04-24 03:00:00       1        5  03        0           0       6
# 4   2021-04-24 04:00:00       1        5  04        0           0       8
# ..                  ...     ...      ...  ..      ...         ...     ...
# 163 2021-04-30 19:00:00       1        4  19        0           1     132
# 164 2021-04-30 20:00:00       1        4  20        0           1     105
# 165 2021-04-30 21:00:00       1        4  21        0           1      71
# 166 2021-04-30 22:00:00       1        4  22        0           1      64
# 167 2021-04-30 23:00:00       1        4  23        0           1      73
#
#      registered  cnt
# 0            83  147
# 1            42   89
# ...

# %% [markdown]
# * lng: 38.710000 - 39.125828
# * lat: (-77.368416)- (-76.825535)
#
# min: 38.71,-77.368416
# max: 39.125828, -76.825535

# %%
df[['start_lat', 'start_lng', 'end_lat', 'end_lng']].describe()
# Out:
#            start_lat      start_lng        end_lat        end_lng
# count  216763.000000  216763.000000  216401.000000  216401.000000
# mean       38.903361     -77.032641      38.902403     -77.032367
# std         0.028552       0.032106       0.028247       0.031971
# min        38.780000     -77.368416      38.710000     -77.368416
# 25%        38.889955     -77.046570      38.889365     -77.046570
# 50%        38.902406     -77.032224      38.902204     -77.032200
# 75%        38.915500     -77.016700      38.912719     -77.016106
# max        39.125828     -76.825535      39.125828     -76.825535

# %%
x = cnt_df['dteday'].to_numpy()
y_casual = cnt_df['casual'].to_numpy()
y_registered = cnt_df['registered'].to_numpy()
fig,ax = plt.subplots(nrows = 1,ncols=1, figsize=(16,10))
ax.plot(x,y_casual,c='b')#,alpha=0.7)
ax.plot(x,y_registered,c='g')#,alpha=0.7)

# %%
import descartes
import geopandas as gpd
from shapely.geometry import Point,Polygon

shape_file_paths = ['../datasets/maps/gis_osm_buildings_a_free_1.shp',
'../datasets/maps/gis_osm_pois_free_1.shp',
'../datasets/maps/gis_osm_landuse_a_free_1.shp',
'../datasets/maps/gis_osm_railways_free_1.shp',
'../datasets/maps/gis_osm_natural_a_free_1.shp',
'../datasets/maps/gis_osm_roads_free_1.shp',
'../datasets/maps/gis_osm_natural_free_1.shp',
'../datasets/maps/gis_osm_traffic_a_free_1.shp',
'../datasets/maps/gis_osm_places_a_free_1.shp',
'../datasets/maps/gis_osm_traffic_free_1.shp',
'../datasets/maps/gis_osm_places_free_1.shp',
'../datasets/maps/gis_osm_transport_a_free_1.shp',
'../datasets/maps/gis_osm_pofw_a_free_1.shp',
'../datasets/maps/gis_osm_transport_free_1.shp',
'../datasets/maps/gis_osm_pofw_free_1.shp',
'../datasets/maps/gis_osm_water_a_free_1.shp',
'../datasets/maps/gis_osm_pois_a_free_1.shp',
'../datasets/maps/gis_osm_waterways_free_1.shp']
# diffs = []
gdfs = []
for file in shape_file_paths:
    gdfs.append(gpd.read_file(file))

# %%
for i,gdf in enumerate(gdfs):
    fig, ax = plt.subplots(figsize=(20,10))
    gdf.plot(ax=ax)
    plt.savefig(f'maps/map{i}.png')

# %%
gdf1=gpd.read_file('../datasets/maps/gis_osm_buildings_a_free_1.shp',)
gdf2=gpd.read_file('../datasets/maps/gis_osm_pois_free_1.shp',)
gdf3=gpd.read_file('../datasets/maps/gis_osm_landuse_a_free_1.shp',)
gdf4=gpd.read_file('../datasets/maps/gis_osm_railways_free_1.shp',)
gdf5=gpd.read_file('../datasets/maps/gis_osm_natural_a_free_1.shp',)
gdf6=gpd.read_file('../datasets/maps/gis_osm_roads_free_1.shp',)
gdf7=gpd.read_file('../datasets/maps/gis_osm_natural_free_1.shp',)
gdf8=gpd.read_file('../datasets/maps/gis_osm_traffic_a_free_1.shp',)
gdf9=gpd.read_file('../datasets/maps/gis_osm_places_a_free_1.shp',)
gdf10=gpd.read_file('../datasets/maps/gis_osm_traffic_free_1.shp',)
gdf11=gpd.read_file('../datasets/maps/gis_osm_places_free_1.shp',)
gdf12=gpd.read_file('../datasets/maps/gis_osm_transport_a_free_1.shp',)
gdf13=gpd.read_file('../datasets/maps/gis_osm_pofw_a_free_1.shp',)
gdf14=gpd.read_file('../datasets/maps/gis_osm_transport_free_1.shp',)
gdf15=gpd.read_file('../datasets/maps/gis_osm_pofw_free_1.shp',)
gdf16=gpd.read_file('../datasets/maps/gis_osm_water_a_free_1.shp',)
gdf17=gpd.read_file('../datasets/maps/gis_osm_pois_a_free_1.shp',)
gdf18=gpd.read_file('../datasets/maps/gis_osm_waterways_free_1.shp')

# %%
fig,axes = plt.subplots()
gdf1.plot(ax =axes)
# Out:
# <AxesSubplot:>

# %%
fig,ax = plt.subplots(figsize=(30,20))
ax.set_aspect('equal')
for gdf in gdfs:
    gdf.set_crs('EPSG:4326')
    gdf.plot(ax =ax)

# %%
shape_file_paths = ['../datasets/maps/gis_osm_buildings_a_free_1',
'../datasets/maps/gis_osm_pois_free_1',
'../datasets/maps/gis_osm_landuse_a_free_1',
'../datasets/maps/gis_osm_railways_free_1',
'../datasets/maps/gis_osm_natural_a_free_1',
'../datasets/maps/gis_osm_roads_free_1',
'../datasets/maps/gis_osm_natural_free_1',
'../datasets/maps/gis_osm_traffic_a_free_1',
'../datasets/maps/gis_osm_places_a_free_1',
'../datasets/maps/gis_osm_traffic_free_1',
'../datasets/maps/gis_osm_places_free_1',
'../datasets/maps/gis_osm_transport_a_free_1',
'../datasets/maps/gis_osm_pofw_a_free_1',
'../datasets/maps/gis_osm_transport_free_1',
'../datasets/maps/gis_osm_pofw_free_1',
'../datasets/maps/gis_osm_water_a_free_1',
'../datasets/maps/gis_osm_pois_a_free_1',
'../datasets/maps/gis_osm_waterways_free_1']
# diffs = []
gdfs = []
crs = []
for file in shape_file_paths:
    gdfs.append(gpd.read_file(file))
    crs.append()

# %%
from bokeh.io import output_file, output_notebook, show
from bokeh.models import (
  GMapPlot, GMapOptions, ColumnDataSource, Circle, LogColorMapper, BasicTicker, ColorBar,
    DataRange1d, PanTool, WheelZoomTool, BoxSelectTool
)
from bokeh.models.mappers import ColorMapper, LinearColorMapper
from bokeh.palettes import Viridis5


map_options = GMapOptions(lat=37.88, lng=-122.23, map_type="roadmap", zoom=6)

plot = GMapPlot(
    x_range=DataRange1d(), y_range=DataRange1d(), map_options=map_options
)
plot.title.text = "Hey look! It's a scatter plot on a map!"

# For GMaps to function, Google requires you obtain and enable an API key:
#
#     https://developers.google.com/maps/documentation/javascript/get-api-key
#
# Replace the value below with your personal API key:
plot.api_key = "AIzaSyBYrbp34OohAHsX1cub8ZeHlMEFajv15fY"

source = ColumnDataSource(
    data=dict(
        lat=housing.latitude.tolist(),
        lon=housing.longitude.tolist(),
        size=housing.median_income.tolist(),
        color=housing.median_house_value.tolist()
    )
)
max_median_house_value = housing.loc[housing['median_house_value'].idxmax()]['median_house_value']
min_median_house_value = housing.loc[housing['median_house_value'].idxmin()]['median_house_value']

#color_mapper = CategoricalColorMapper(factors=['hi', 'lo'], palette=[RdBu3[2], RdBu3[0]])
#color_mapper = LogColorMapper(palette="Viridis5", low=min_median_house_value, high=max_median_house_value)
color_mapper = LinearColorMapper(palette=Viridis5)

circle = Circle(x="lon", y="lat", size="size", fill_color={'field': 'color', 'transform': color_mapper}, fill_alpha=0.5, line_color=None)
plot.add_glyph(source, circle)

color_bar = ColorBar(color_mapper=color_mapper, ticker=BasicTicker(),
                     label_standoff=12, border_line_color=None, location=(0,0))
plot.add_layout(color_bar, 'right')

plot.add_tools(PanTool(), WheelZoomTool(), BoxSelectTool())
#output_file("gmap_plot.html")
output_notebook()

show(plot)
