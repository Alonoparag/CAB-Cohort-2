# %%
from IPython.display import Image

# %% [markdown]
# * at least 5 visualisations
# * findings
# * last slide - next steps
# * -8 slide
# * three key insights
# * Cover Slide
# * Agenda – What will be discussed in the presentation?
# * Background – What is the context of this project?
# * Descriptions and location of related data.
# * Any known issues with the data and how you plan to address them.
# * Descriptive/ Inferential statistics you gathered as an initial step in analysis.
# * High-Level Recommendations – Three or more recommendations about the existing data. What would you change or add to the data?
# * Closing Slide
# * DO NOT forget to tell a story with your Analysis!

# %% [markdown]
# # Cover
# Exploring analytical charachteristics of wine and their correlation to rated wine quality
#
# Created by Alon Parag
# Date: 07.05.2021
# Client: Blueberry Winery
#
# data: Modeling wine preferences by data mining from physicochemical properties by Cortez et al.(2009)

# %% [markdown]
# # Background:
# * What is the discussed matter:
#     * Perliminary analysis of physicochemical properties of wine in relation to wine quality
# * Why is it relevant to the client:
#     * Wine quality could have an effect on wine price and brand value.
#     * An informed intervention during production of wine could affect specific wine properties.
#     * Therefore, If there is a correlation between physicochemical properties to wine quality, and if wine quality could be predicted from properties, Blueberry Winery could act on this information to improve their wine quality, increase revenue and build their brand name.
# * What are the insights that will be discussed

# %% [markdown]
# # Null Hypothesis:
# * Wine qualities have the same average physicochemical properties
# * Confidence interval: 95%

# %% [markdown]
# # Description:
# * Data is sourced from a study carried by Cortez et al. in 2009 called Modeling wine preferences by data mining from physicochemical properties.
# * the data includes samples of 4898 white wines and 1599 red wines
# * Numerical variables and their sources
# * The following properties were taken from the wine analysis:
#     * fixed acidity
#     * volatile acidity
#     * citric acid
#     * residual sugar
#     * chlorides
#     * free sulfur dioxide
#     * total sulfur dioxide
#     * density
#     * pH
#     * sulphates
#     * alcohol
# * in addition, each wine received a quality score obtained by testers, on a scale from 0 (lowest) to 10 (highest).
# * Since most of the samples (3915 wines out of 6497) has a quality score of 6 or 7, I added another property called "Quality Label", rated low(quality under 6), medium(quality of 6 or 7), and high(quality above 7) to simplify preliminary analysis.
# * I also classified the wines to their respective type, red or white.
# * Results from analysis shows that for except fo pH levels, wines from the 3 quality groups have significantly different physicochemical properties.

# %% [markdown]
# * Fixed acidity: acids are major wine properties and contribute greatly to the wine’s taste. Usually, the total acidity is divided into two groups: the volatile acids and the nonvolatile or fixed acids. Among the fixed acids that you can find in wines are the following: tartaric, malic, citric, and succinic. This variable is expressed in $\frac{g(tartaricacid)}{liter}$ in the data sets.
#
# * Volatile acidity: the volatile acidity is basically the process of wine turning into vinegar. In the U.S, the legal limits of Volatile Acidity are 1.2 $\frac{g}{L}$ for red table wine and 1.1 $\frac{g}{L}$ for white table wine. In these data sets, the volatile acidity is expressed in $\frac{g(aceticacid)}/{l}$. Excessive volatile acidity may result in lower wine quality
#
# * Citric acid is one of the fixed acids that you’ll find in wines. It’s expressed in $\frac{g}{l}$ in the two data sets. Residual sugar typically refers to the sugar remaining after fermentation stops, or is stopped. It’s expressed in $\frac{g}{l}$ in the red and white data.
#
# * Chlorides can be a significant contributor to saltiness in wine. Here, you’ll see that it’s expressed in $\frac{g(sodiumchloride)}{l}$.
# * SO2 (sulfur dioxide) is added periodically throughout the winemaking process and plays a critical role in quality winemaking. Sulfur serves two main purposes. It prevents the wine from reacting with oxygen which can cause browning and off-odors (oxidation), and it inhibits the growth of bacteria and undesirable wild yeasts in the grape juice and wine.
#
# * Free sulfur dioxide: the part of the sulfur dioxide that is added to a wine and that is lost into it is said to be bound, while the active part is said to be free. The winemaker will always try to get the highest proportion of free sulfur to bind. This variable is expressed in $\frac{mg}{l}$ in the data.
#
# * Total sulfur dioxide is the sum of the bound and the free sulfur dioxide (SO2). Here, it’s expressed in $\frac{mg}{l}$. There are legal limits for sulfur levels in wines: in the EU, red wines can only have 160$\frac{mg}{L}$, while white and rose wines can have about 210$\frac{mg}{L}$. Sweet wines are allowed to have 400$\frac{mg}{L}$. For the US, the legal limits are set at 350$\frac{mg}{L}$, and for Australia, this is 250$\frac{mg}{L}$.
#
# * Density is generally used as a measure of the conversion of sugar to alcohol. Here, it’s expressed in $\frac{g}{ml}$.
#
# * pH or the potential of hydrogen is a numeric scale to specify the acidity or basicity the wine. As you might know, solutions with a pH less than 7 are acidic, while solutions with a pH greater than 7 are basic. With a pH of 7, pure water is neutral. Most wines have a pH between 2.9 and 3.9 and are therefore acidic.
#
# * Sulfates are to wine as gluten is to food. You might already know sulfites from the headaches that they can cause. They are a regular part of winemaking around the world and are considered necessary. In this case, they are expressed in \frac{g(potassiumsulphate)}{l}$.
#
# * Alcohol: wine is an alcoholic beverage, and as you know, the percentage of alcohol can vary from wine to wine. It shouldn’t be surprised that this variable is included in the data sets, where it’s expressed in % vol. Concentration above 15% halts the fermentation process of wine
#
# * Quality: wine experts graded the wine quality between 0 (very bad) and 10 (very excellent). The eventual number is the median of at least three evaluations made by those same wine experts. Some analysts might combine these levels to *Low, Medium & High-Quality wines.

# %% [markdown]
# # Insights:
#
# * One slide per insight, summarized by a sentence or two and a graph
# * each slide has summary of property (AND UNITS)
# * color scheme is orange background with purple underline.
# * for every quality label property, there's a top limit of value that could be used to exclude a wine from that quality label.

# %% [markdown]
# # Insights regarding Fixed acidity
# * low quality wine will have on average 0.166 higher fixed acidity than medium quality wine
# * medium quality wine will have on avergage 0.313 higher fixed acidity than high quality wine
#     * a wine with lower fixed acidity could indicate a higher quality wine

# %%
Image('plots/fixed_acidity_box.png')

# %% [markdown]
# # Pairwise analysis for  Volatile acidity
# * low quality wine have by average 0.1 more volatile acids than high quality, and 0.09 more than medium

# %%
Image('plots/fixed_acidity_box.png')

# %% [markdown]
# # Pairwise analysis for  Citric acid
# * Low quality wine has on average 0.029 lower count than high quality, and on average 0.023 higher than medium quality

# %%
Image('plots/citric acid_by_quality_label.png')

# %% [markdown]
# # Pairwise analysis for  Residual sugar
# * Low quality wine has on average 0.32 more residual sugar than medium quality wine

# %% [markdown]
# # Pairwise analysis for  Chlorides
# * Low quality wine has on average 0.01 more chlorides than medium quality wine, and on average 0.236 more chlorides than high quality wine
# * medium quality wine has on average 0.01 more chlorides than high quality wine

# %%
Image('plots/chlorides_box.png')

# %% [markdown]
# # Pairwise analysis for  Free sulfur dioxide
# * Low quality wine has one average 1.4798 less free sulfur dioxide than medium quality wine, and on average 5.024 less free sulfur dioxide than high quality wine
# * Medium quality wine has on average 3.54 less free sulfur dioxide than high quality wine

# %%
Image('plots/free_sulfur_dioxide_box.png')

# %% [markdown]
# # Pairwise analysis for  Total sulfur dioxide
# * Low quality wine has on average 5.7713 more sulfur dioxie than medium quality wine

# %%
Image('plots/total sulfur dioxide_by_quality_label.png')

# %% [markdown]
# # Pairwise analysis for  Density
# * Low quality wine has on average 0.0016 higher density than medium quality wine, and 0.0033 higher density than high quality wine
# * Medium quality wine has on average 0.0017 higher density than high quality wine

# %%
Image('plots/density_by_quality_label.png')

# %% [markdown]
# # Pairwise analysis for  Sulphates
# * Low quality wine has on average 0.0123 less sulphates than medium quality wine

# %%
Image('plots/sulphates_box.png')

# %% [markdown]
# # Pairwise analysis for  Alcohol
# * Low quality wine has on average 0.9341 less alcohol than medium quality wine, and on average 1.8179 less alcohol than high quality wine
# * Medium quality wine has on average 0.8838 less alcohol than high quality wine.

# %%
Image('plots/alcohol_by_quality_label.png')

# %% [markdown]
# # Insights from correlation map

# %% [markdown]
# ## total sulfur dioxide and residual sugar:
# Correlation coefficient: 0.495482

# %%
Image('plots/reg/reg-residual sugar-total sulfur dioxide.png')

# %% [markdown]
# ## Residual sugar and density:
# Correlation coefficient: 0.55

# %%
Image('plots/reg/reg-residual sugar-density.png')

# %% [markdown]
# ## Total sulfur dioxide and free sulfur dioxide:
# Correlation coeficient: 0.720934

# %%
Image('plots/reg/reg-total sulfur dioxide-free sulfur dioxide.png')

# %% [markdown]
# ## Alcohol and density:
# Correlation coeficient -0.686745

# %%
Image('plots/reg/reg-density-alcohol.png')

# %% [markdown]
# # Recommendations
# * ABOUT THE DATA:
# * More data about wines with quality rating of 8,9 and 10 is required

# %% [markdown]
# # Closing slide

# %% [markdown]
# ## Notes from presentation
# * Turn complex statements into simple, understandable to the commoner statements
# * First explore the data with no a-priori assumptions, write down insights, and then think (or read) the client's agenda/objectives, and look what the data tells about it
# * When plot is skewed by high values for one bin, truncate that bin.
# * when testing an intervention (seo), look for change over time, specifically time before intervention and as much possible parallel time after intervention.
# * Keep it minimal - Write a story in words, Shape it into a presentation and only then insert supporting plots and numerical/statistical data
# * ABOUT DATASET represents data dependent variables
# * STEPS INVOLVE
# * Wordcloud for categorical data are much more useful than numbers and lines/graphs.
# Make graps interacitive!!
# * Mouseover effects for graphs.
# * Make sure that graphs have legend for graph colors, y scale and x scale, with uits when needed. also labels!
# For long presentatoion after exploring data have conclusions with insights
# * check for statistical fluctuations (check for statistical significance for all data)
