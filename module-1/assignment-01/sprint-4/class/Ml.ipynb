# %% [markdown]
# ### Programming: rules + input = result
# ### MachineLearning: Input + result = rules ,
#
# ### using ML: new_input + rules = new_result.  (prediction)  # we dont defone rules

# %%
## Simplest example of MAchine Learning:


# #############
# def(x,y):
#     r = some operation 
#     return r
# #############

# Example1:       
    
# input1: 2,3   , result = 5    
# input2: 5,7 , result = 12
# input3: 4, 20, result = 24
    
# : regression    

    
# Example2:
    
# input1: 4 ,    result = 0
# input2: 7 ,    result = 0
# input3: 8 ,    result = 1    
# input4: 10,    result = 1    
# input5: 1 ,    result = 0    
# input6, 3.7 ,  result = 0 
# input7, 12.8 , result = 1

# : classification

# Example3:
    
# input1: 4,6 ,    result = 0
# input3: 8,8   result = 1    
# input4: 10,4    result = 1    
# input5: 1 ,11    result = 0    
# input6, 3.7,4  result = 0 
# input7, 12.8,54 , result = 1


#Use correlation matrix for feature selection

# %% [markdown]
# ##### Preprocessing
#
# ## EDA for feature selection
#
# ###### Min_max scalar or standard scalar

# %%
# Simplest example: 2 features
    
#     1) Age
#     2) Salary
    
# why Standardise: Range is different. 
#     Major reason: Change by one value affects if it's age :
#     change by one value in salary will not affect as much

###########
##
## Min Max scalar |: (X - X_min) / (X_max - X_min) 
###########

##########
##
##standard Scalar: (X - X_mean) / X_std 
##########

from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ##### Label Encoding

# %%
# All operations: using numbers

# need to convert: red, black : 0,1
## in case of quality: low, medium and high : 0,1,2 

# and so on.... ....

from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# #### Train test split

# %%
# Use some data for learnign the rules: (train data )
# use rest of the data to test the rules (test data)
from sklearn.model_selection import train_test_split

# %% [markdown]
# ##### Regression

# %%
from IPython.display import Image

# %%
Image('lr0.png')

# %% [markdown]
# ![lr0.png](attachment:lr0.png)

# %%
# predicting continuos values

# %% [markdown]
# #### logistic regression

# %% [markdown]
# ![lr.png](attachment:lr.png)

# %%
Image('lr.png')

# %% [markdown]
# ![lr1.jpeg](attachment:lr1.jpeg)

# %%
Image('lr1.jpeg')

# %%
## Balancing the data
